# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Ronald Barbour__
# <br>Data Analyst

# %% [markdown]
# _I am interested in Data Science because I have always been an analytical thinker.  I love solving problems and I love helping others.  I would like to use data to make this world a better place for future generations whether that means discovering ways to live healthier and happier, solving crimes, or increasing efficiency for customers looking for products._

# %% [markdown]
# ### My code below is supposed to print a statement to the screen greeting my fellow classmates.

# %%
print("Hello, fellow IBM Data Science Students!")
# Out:
# Hello, fellow IBM Data Science Students!

# %% [markdown]
# The 3 reasons I am excited about being in this course with you are:
#
#  - We are all here to learn/upskill.
#  - We are in this community together.
#  - ~We can be best friends and go to the lake and hiking and camping and have a bonfire and tell ghost stories and feed each other s'mores. (Sorry, I wanted to include a strikethrough example too. lol.  We can actually do all of those things together if you happen to be my spouse.  Spoiler, you are not her.)~
#  - We can make this world a better place for our children and future generations using data.
#  <br><br>
#  __[Feel free to connect with me on LinkedIn here.](https://www.linkedin.com/in/ronaldbarbour/)__
#  <br><br><br>
#  Here is my LinkedIn profile picture so you know you have the right classmate:
# <br><div> <img src="https://media.licdn.com/dms/image/C4E03AQFvpsB29HjLjg/profile-displayphoto-shrink_800_800/0/1663915338699?e=1684972800&v=beta&t=jbeiBEDcuMbjUdKCo6fOZSmtVpzmALt2I5MzFl1XG3I" alt="Ronald Barbour's LinkedIn profile picture." width=200 /></div>
